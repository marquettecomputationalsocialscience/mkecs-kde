# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sqlite3

survey_data = pd.read_csv('data/questionnaire.csv')
maps_data = pd.read_csv('data/map-data.csv')




survey_data['participant_id']=survey_data['Q51_1'].astype(np.int64)

survey_data.head(5)
survey_data.describe()
# Out:
#        Duration (in seconds)  LocationLatitude  LocationLongitude      Q51_1  \
# count              52.000000         52.000000          52.000000  52.000000
# mean             8984.480769         41.976280         -89.808005  31.442308
# std             20791.185069          2.094470           3.948738  18.654142
# min               604.000000         37.751007         -97.821999   1.000000
# 25%              1744.500000         43.038895         -87.906502  15.750000
# 50%              2739.500000         43.038895         -87.906502  29.500000
# 75%              4499.750000         43.038895         -87.906502  48.500000
# max             92662.000000         43.038895         -87.651703  62.000000
#
#             Q2_1       Q3_1       Q4_1       Q5_1       Q6_1       Q7_1  \
# count  52.000000  52.000000  52.000000  52.000000  52.000000  52.000000
# mean    8.769231   1.288462   3.480769  12.269231   6.576923   4.480769
# std     4.080635   1.288509   3.090088   4.428585   4.074532   5.108587
# min     1.000000   0.000000   0.000000   1.000000   0.000000   0.000000
# 25%     5.000000   1.000000   1.000000  10.000000   3.000000   1.000000
# 50%     8.500000   1.000000   3.000000  13.000000   6.500000   2.000000
# 75%    12.000000   2.000000   5.000000  15.000000   9.250000   7.000000
# max    17.000000   7.000000  10.000000  20.000000  16.000000  18.000000
#
#            Q30_1  Q33_9_TEXT      Q44_1  Q51_1 - Sentiment Score  \
# count  52.000000         0.0  52.000000                50.000000
# mean   27.730769         NaN   3.673077                 0.200000
# std    10.853960         NaN   2.357476                 0.571429
# min    20.000000         NaN   0.000000                -1.000000
# 25%    21.000000         NaN   2.000000                 0.000000
# 50%    23.000000         NaN   4.000000                 0.000000
# 75%    30.000000         NaN   5.000000                 1.000000
# max    76.000000         NaN   9.000000                 1.000000
#
#        Q51_1 - Sentiment Polarity  participant_id
# count                        50.0       52.000000
# mean                          0.0       31.442308
# std                           0.0       18.654142
# min                           0.0        1.000000
# 25%                           0.0       15.750000
# 50%                           0.0       29.500000
# 75%                           0.0       48.500000
# max                           0.0       62.000000

# %%
data=pd.merge(maps_data, survey_data, on="participant_id", how="left")

data.to_csv('data/masterData.csv', sep='\t')

# %%
data.describe()
data.head(5)
# Out:
#    new_part_id  participant_id  group_num background   kernel1  bandwidth1  \
# 0            1               1          2       tech  gaussian      0.0025
# 1            2               2          1       none  gaussian      0.0050
# 2            3               3          1       none  gaussian      0.0050
# 3            4               4          1       none    linear      0.0050
# 4            5               6          1       none  gaussian      0.0050
#
#      metric1  min_hotspots1  max_hotspots1  min_circles1  ...  Q41  \
# 0  euclidean              4             20             5  ...   No
# 1  euclidean             13             11            17  ...  Yes
# 2  euclidean             10             24            50  ...  Yes
# 3  euclidean              5             15             8  ...   No
# 4  euclidean              9             16            19  ...  Yes
#
#                           Q42                Q43 Q44_1  \
# 0  Neither agree nor disagree     Somewhat agree     5
# 1              Somewhat agree  Somewhat disagree     2
# 2                       Agree     Somewhat agree     9
# 3                       Agree              Agree     5
# 4                       Agree     Somewhat agree     1
#
#                       Q45                             Q46  Q51_1 - Sentiment  \
# 0                 Neutral                         Neutral                NaN
# 1    Somewhat Libertarian  Somewhat fiscally conservative            Neutral
# 2           Authoritarian           Fiscally conservative            Neutral
# 3                 Neutral  Somewhat fiscally conservative            Neutral
# 4  Somewhat Authoritarian  Somewhat fiscally conservative            Neutral
#
#    Q51_1 - Sentiment Score Q51_1 - Sentiment Polarity  Q51_1 - Topics
# 0                      NaN                        NaN             NaN
# 1                      0.0                        0.0         Unknown
# 2                      0.0                        0.0         Unknown
# 3                      0.0                        0.0         Unknown
# 4                      0.0                        0.0         Unknown
#
# [5 rows x 85 columns]

# %%
data_g1= data[data['group_num']==1]
data_g1.head(5)
data_g1.to_csv('data/g1.csv', sep='\t')
# Out:
#    new_part_id  participant_id  group_num background   kernel1  bandwidth1  \
# 1            2               2          1       none  gaussian       0.005
# 2            3               3          1       none  gaussian       0.005
# 3            4               4          1       none    linear       0.005
# 4            5               6          1       none  gaussian       0.005
# 5            6               7          1       none    tophat       0.005
#
#      metric1  min_hotspots1  max_hotspots1  min_circles1  ...  Q41  \
# 1  euclidean             13             11            17  ...  Yes
# 2  euclidean             10             24            50  ...  Yes
# 3  euclidean              5             15             8  ...   No
# 4  euclidean              9             16            19  ...  Yes
# 5  manhattan             50             90            50  ...  Yes
#
#               Q42                Q43 Q44_1                     Q45  \
# 1  Somewhat agree  Somewhat disagree     2    Somewhat Libertarian
# 2           Agree     Somewhat agree     9           Authoritarian
# 3           Agree              Agree     5                 Neutral
# 4           Agree     Somewhat agree     1  Somewhat Authoritarian
# 5  Strongly agree              Agree     5    Somewhat Libertarian
#
#                               Q46  Q51_1 - Sentiment  Q51_1 - Sentiment Score  \
# 1  Somewhat fiscally conservative            Neutral                      0.0
# 2           Fiscally conservative            Neutral                      0.0
# 3  Somewhat fiscally conservative            Neutral                      0.0
# 4  Somewhat fiscally conservative            Neutral                      0.0
# 5                         Neutral            Neutral                      0.0
#
#   Q51_1 - Sentiment Polarity  Q51_1 - Topics
# 1                        0.0         Unknown
# 2                        0.0         Unknown
# 3                        0.0         Unknown
# 4                        0.0         Unknown
# 5                        0.0         Unknown
#
# [5 rows x 85 columns]

# %%
data_g2= data[data['group_num']==2]
data_g2.head(5)
data_g2.to_csv('data/g2.csv', sep='\t')
# Out:
#     new_part_id  participant_id  group_num background   kernel1  bandwidth1  \
# 0             1               1          2       tech  gaussian      0.0025
# 6             7               8          2       tech  gaussian      0.0050
# 28           29              32          2       tech  gaussian      0.0050
# 29           30              34          2       tech  gaussian      0.0050
# 34           35              42          2       tech  gaussian      0.0050
#
#       metric1  min_hotspots1  max_hotspots1  min_circles1  ...  Q41  \
# 0   euclidean              4             20             5  ...   No
# 6   euclidean             40             55            20  ...   No
# 28  euclidean             11             17            49  ...  Yes
# 29  euclidean             12             15            60  ...  Yes
# 34  euclidean              6              9            80  ...  Yes
#
#                            Q42                         Q43 Q44_1  \
# 0   Neither agree nor disagree              Somewhat agree     5
# 6               Somewhat agree  Neither agree nor disagree     5
# 28                       Agree                       Agree     3
# 29                       Agree              Somewhat agree     4
# 34              Strongly agree           Strongly disagree     7
#
#                      Q45                             Q46  Q51_1 - Sentiment  \
# 0                Neutral                         Neutral                NaN
# 6   Somewhat Libertarian           Fiscally conservative            Neutral
# 28  Somewhat Libertarian  Somewhat fiscally conservative            Neutral
# 29               Neutral       Somewhat fiscally Liberal           Positive
# 34         Authoritarian           Fiscally conservative            Neutral
#
#     Q51_1 - Sentiment Score Q51_1 - Sentiment Polarity  Q51_1 - Topics
# 0                       NaN                        NaN             NaN
# 6                       0.0                        0.0         Unknown
# 28                      0.0                        0.0         Unknown
# 29                      1.0                        0.0         Unknown
# 34                      0.0                        0.0         Unknown
#
# [5 rows x 85 columns]

# %%
data_g3= data[data['group_num']==3]
data_g3.head(5)
data_g3.to_csv('data/g3.csv', sep='\t')
# Out:
#     new_part_id  participant_id  group_num    background   kernel1  \
# 13           14              16          3  professional  gaussian
# 39           40              50          3  professional  gaussian
# 42           43              53          3  professional  gaussian
# 48           49              59          3  professional  gaussian
# 49           50              60          3  professional  gaussian
#
#     bandwidth1    metric1  min_hotspots1  max_hotspots1  min_circles1  ...  \
# 13       0.005  euclidean             10             16            15  ...
# 39       0.005  euclidean             10             15            18  ...
# 42       0.005  euclidean              8             22            18  ...
# 48       0.005  euclidean             10             20            50  ...
# 49       0.005  euclidean              4              6            18  ...
#
#     Q41             Q42             Q43 Q44_1                     Q45  \
# 13   No  Somewhat agree           Agree     1             Libertarian
# 39   No  Strongly agree           Agree     2    Somewhat Libertarian
# 42   No           Agree  Strongly agree     5                 Neutral
# 48   No           Agree           Agree     2                 Neutral
# 49  Yes  Strongly agree  Strongly agree     7  Somewhat Authoritarian
#
#                                Q46  Q51_1 - Sentiment  \
# 13       Somewhat fiscally Liberal           Positive
# 39       Somewhat fiscally Liberal           Positive
# 42  Somewhat fiscally conservative           Negative
# 48                         Neutral           Negative
# 49           Fiscally conservative            Neutral
#
#     Q51_1 - Sentiment Score Q51_1 - Sentiment Polarity  Q51_1 - Topics
# 13                      1.0                        0.0         Unknown
# 39                      1.0                        0.0         Unknown
# 42                     -1.0                        0.0         Unknown
# 48                     -1.0                        0.0         Unknown
# 49                      0.0                        0.0         Unknown
#
# [5 rows x 85 columns]

# %%
survey_data.Q30_1 = pd.to_numeric(survey_data.Q30_1.iloc[2:], downcast='integer')

under18 = survey_data[survey_data["Q30_1"] < 18]

age18to24 = survey_data[survey_data["Q30_1"] >= 18]
age18to24 = age18to24[age18to24["Q30_1"] < 25]

age25to44 = survey_data[survey_data["Q30_1"] >= 25]
age25to44 = age25to44[age25to44["Q30_1"] < 44]

age45to64 = survey_data[survey_data["Q30_1"] >= 45]
age45to64 = age45to64[age45to64["Q30_1"] < 64]

over65 = survey_data[survey_data["Q30_1"] >= 65]

# %%
ageCounts = pd.DataFrame({'counts': [19, 18, 2, 1]}, index=['18 to 24', '25 to 44', '45 to 64', '65 or over'])
plot = ageCounts.plot.pie(y='counts', figsize=(6,6))

# %%
# counts of age groups
ageCounts.plot.bar(y='counts', figsize=(6,6))

# %%
lessThanHSDiploma = survey_data[survey_data['Q34'] == "Less than high school diploma"]
ged = survey_data[survey_data['Q34'] == "High school diploma or GED"]
someCollege = survey_data[survey_data['Q34'] == "Some college"]
currentlyEnrolledCollege = survey_data[survey_data['Q34'] == "Currently enrolled in college"]
bachelors = survey_data[survey_data['Q34'] == "Bachelor's degree"]
masters = survey_data[survey_data['Q34'] == "Master's degree"]
doctorate = survey_data[survey_data['Q34'] == "Doctorate degree"]

educationCounts = pd.DataFrame({'counts': [len(lessThanHSDiploma), len(ged), len(someCollege),
                                          len(currentlyEnrolledCollege), len(bachelors), len(masters),
                                          len(doctorate)]},
                              index=['less than HS diploma', 'GED', 'some college', 'currently enrolled in college',
                                    'bachelors', 'masters', 'doctorate'])
educationCounts.plot.bar(y='counts', figsize=(6,6))

# %%
white = survey_data[survey_data['Q32'] == "White"]
africanAmerican = survey_data[survey_data['Q32'] == "Black or African American"]
eastAsian = survey_data[survey_data['Q32'] == "East Asian"]
southAsian = survey_data[survey_data['Q32'] == "South Asian"]
pacificIslanderHawaiian = survey_data[survey_data['Q32'] == "Pacific Islander or Hawaiian"]
middleEastern = survey_data[survey_data['Q32'] == "Middle Eastern or Arab"]
nativeAmerican = survey_data[survey_data['Q32'] == "Native American or First Nations"]
hispanic = survey_data[survey_data['Q32'] == "Central American Native, South American Native, Chicano, or Mestizo"]
other = survey_data[survey_data['Q32'] == "Other (please specify)"]

raceCounts = pd.DataFrame({'counts': [len(white), len(africanAmerican), len(eastAsian),
                                     len(southAsian), len(pacificIslanderHawaiian), len(middleEastern),
                                     len(nativeAmerican), len(hispanic), len(other)]},
                         index=['white', 'african american', 'east asian', 'south asian', 'pacific islander or hawaiian',
                               'middle eastern', 'native american or first nations', 'central american native, south american native, chicano, or mestizo',
                               'other'])
raceCounts.plot.bar(y='counts', figsize=(6,6))
